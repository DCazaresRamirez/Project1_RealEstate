# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file_path = 'HUD_PIP_Data.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#   State  Number of CoCs Overall Homeless Sheltered ES Homeless  \
# 0    AK             2.0           1642.0                 898.0
# 1    AL             8.0           5452.0                1452.0
# 2    AR             9.0           3836.0                1251.0
# 3    AS             0.0
# 4    AZ             3.0          14646.0                3934.0
#
#   Sheltered TH Homeless Sheltered Total Homeless Unsheltered Homeless  \
# 0                 489.0                   1387.0                255.0
# 1                2344.0                   3796.0               1656.0
# 2                1034.0                   2285.0               1551.0
# 3
# 4                4684.0                   8618.0               6028.0
#
#   Overall Homeless Individuals Sheltered ES Homeless Individuals  \
# 0                       1062.0                             618.0
# 1                       4184.0                            1210.0
# 2                       2987.0                             985.0
# 3
# ...

# %%
#Ages 18 to 24 for AZ, CA, CO, HI, MA, UT, LA, ND, MS, IL, NM

# %%
# List of state codes you're interested in
state_codes = ['AZ']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Age 18 to 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Age 18 to 24'] = pd.to_numeric(state_data['Overall Homeless - Age 18 to 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Age 18 to 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Arizona - Ages 18 to 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless 18 to 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['CA']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Age 18 to 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Age 18 to 24'] = pd.to_numeric(state_data['Overall Homeless - Age 18 to 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Age 18 to 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in California - Ages 18 to 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless 18 to 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['CO']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Age 18 to 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Age 18 to 24'] = pd.to_numeric(state_data['Overall Homeless - Age 18 to 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Age 18 to 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Colorado - Ages 18 to 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless 18 to 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['HI']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Age 18 to 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Age 18 to 24'] = pd.to_numeric(state_data['Overall Homeless - Age 18 to 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Age 18 to 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Hawaii - Ages 18 to 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless 18 to 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['MA']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Age 18 to 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Age 18 to 24'] = pd.to_numeric(state_data['Overall Homeless - Age 18 to 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Age 18 to 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Massachussetts - Ages 18 to 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless 18 to 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['UT']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Age 18 to 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Age 18 to 24'] = pd.to_numeric(state_data['Overall Homeless - Age 18 to 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Age 18 to 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Utah - Ages 18 to 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless 18 to 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['LA']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Age 18 to 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Age 18 to 24'] = pd.to_numeric(state_data['Overall Homeless - Age 18 to 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Age 18 to 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Louisiana - Ages 18 to 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless 18 to 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['ND']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Age 18 to 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Age 18 to 24'] = pd.to_numeric(state_data['Overall Homeless - Age 18 to 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Age 18 to 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in North Dakota - Ages 18 to 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless 18 to 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['IL']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Age 18 to 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Age 18 to 24'] = pd.to_numeric(state_data['Overall Homeless - Age 18 to 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Age 18 to 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Illinois - Ages 18 to 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless 18 to 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['NM']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Age 18 to 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Age 18 to 24'] = pd.to_numeric(state_data['Overall Homeless - Age 18 to 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Age 18 to 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in New Mexico - Ages 18 to 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless 18 to 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['MS']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Age 18 to 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Age 18 to 24'] = pd.to_numeric(state_data['Overall Homeless - Age 18 to 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Age 18 to 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Missouri - Ages 18 to 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless 18 to 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
#----------------------------------------------------------------------------------------------------------------------------

# %%
#Ages over 24 for AZ, CA ,CO, HI, MA, UT, LA, ND, IL, NM, MS

# %%
# List of state codes you're interested in
state_codes = ['AZ']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Over 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Over 24'] = pd.to_numeric(state_data['Overall Homeless - Over 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Over 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Arizona - Over 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless Over 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['CA']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Over 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Over 24'] = pd.to_numeric(state_data['Overall Homeless - Over 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Over 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in California - Over 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless Over 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['CO']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Over 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Over 24'] = pd.to_numeric(state_data['Overall Homeless - Over 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Over 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Colorado - Over 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless Over 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['HI']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Over 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Over 24'] = pd.to_numeric(state_data['Overall Homeless - Over 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Over 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Hawaii - Over 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless Over 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['MA']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Over 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Over 24'] = pd.to_numeric(state_data['Overall Homeless - Over 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Over 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Massachussetts - Over 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless Over 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['UT']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Over 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Over 24'] = pd.to_numeric(state_data['Overall Homeless - Over 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Over 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Utah - Over 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless Over 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['LA']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Over 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Over 24'] = pd.to_numeric(state_data['Overall Homeless - Over 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Over 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Louisiana - Over 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless Over 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['ND']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Over 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Over 24'] = pd.to_numeric(state_data['Overall Homeless - Over 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Over 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in North Dakota - Over 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless Over 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['IL']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Over 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Over 24'] = pd.to_numeric(state_data['Overall Homeless - Over 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Over 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Illinois - Over 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless Over 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['NM']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Over 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Over 24'] = pd.to_numeric(state_data['Overall Homeless - Over 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Over 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in New Mexico - Over 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless Over 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['MS']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Over 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Over 24'] = pd.to_numeric(state_data['Overall Homeless - Over 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Over 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless in Missouri - Over 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless Over 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
#All combined minus CA

# %%
# List of state codes you're interested in
state_codes = ['AZ', 'UT', 'CO','MA','LA','ND','MS','IL','NM','HI',]  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Age 18 to 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Age 18 to 24'] = pd.to_numeric(state_data['Overall Homeless - Age 18 to 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Age 18 to 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless - Ages 18 to 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless 18 to 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
# List of state codes you're interested in
state_codes = ['AZ', 'UT', 'CO','MA','LA','ND','MS','IL','NM','HI']  

# Iterate over each state code
for state_code in state_codes:
    # Filter the DataFrame to get data only for the specified state and years from 2013 to 2023
    state_data = df[(df['State'] == state_code) & (df['Year'].between(2013, 2023))].copy()

    # Convert the "Overall Homeless - Over 24" column to numeric values, ignoring errors
    state_data['Overall Homeless - Over 24'] = pd.to_numeric(state_data['Overall Homeless - Over 24'], errors='coerce')

    # Plot line chart for each state
    plt.plot(state_data['Year'], state_data['Overall Homeless - Over 24'], marker='o', linestyle='-', label=state_code)

plt.title('Overall Homeless - Over 24 (2013-2023)')  # Title of the plot
plt.xlabel('Year')  # Label for the x-axis
plt.ylabel('Overall Homeless Over 24')  # Label for the y-axis
plt.grid(True)  # Show grid
plt.legend()  # Show legend with state codes
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot
